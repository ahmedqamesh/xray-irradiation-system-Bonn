# %% [markdown]
# # Characterization of the X-ray Irradiation System @ Bonn

# %%
from analysis import plotting_Calibration
from analysis import analysis
from matplotlib.backends.backend_pdf import PdfPages
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: right;
    vertical-align: middle;
}
</style>
""")
# %matplotlib inline
Directory = "Calibration_Curves/"
pdf_file = 'output_data/CalibrationCurve_Bonn.pdf'
tests = ["without_Al_Filter", "with_Al_Filter"]
depth = ["3cm", "5cm", "8cm", "51cm"]
PdfPages = PdfPages(pdf_file)
filename = "/home/silab62/git/XrayMachine_Bonn/tests/without_Al_Filter/beamspot/60cm/beamspot_60cm.h5"
p =plotting_Calibration.Plotting()

# %% [markdown]
# ## Photodiodes Dosimetry Calibration

# %%
p.diode_calibration(PdfPages=PdfPages, Directory=Directory, diodes=["A","B","C"])

# %% [markdown]
# ## Temprature Effect On the Diode Calibration

# %%
p.calibration_temperature(data="temperature_dose.h5", Directory=Directory, PdfPages=PdfPages)

# %% [markdown]
# ## Determination of the Opening Angle

# %%
p.opening_angle(Directory=Directory, tests=tests,PdfPages=PdfPages)

# %% [markdown]
# ## Measurement of the Absorbed Dose vs. Depth

# %%
p.dose_depth(tests=tests, Directory=Directory, PdfPages=PdfPages)

# %% [markdown]
# ## Measurement of the Absorbed Dose vs. Tube Current

# %%
p.dose_current(stdev=0.04, PdfPages=PdfPages, Directory=Directory, depth= ["3cm", "5cm", "8cm", "51cm"], table=True,Voltages=["40kV", "30kV"])
# Out:
# 2019-11-29 10:38:10,864-[Plotting]- INFO    Get the calibration curves for each current
# 2019-11-29 10:38:10,883-[Plotting]- INFO    Start Plotting calibration curves at 3cm , 40kV
# 2019-11-29 10:38:10,894-[Plotting]- INFO    Start Plotting calibration curves at 3cm , 30kV
# 2019-11-29 10:38:11,594-[Plotting]- INFO    Start Plotting calibration curves at 5cm , 40kV
# 2019-11-29 10:38:11,603-[Plotting]- INFO    Start Plotting calibration curves at 5cm , 30kV
# 2019-11-29 10:38:12,241-[Plotting]- INFO    Start Plotting calibration curves at 8cm , 40kV
# 2019-11-29 10:38:12,249-[Plotting]- INFO    Start Plotting calibration curves at 8cm , 30kV
# 2019-11-29 10:38:12,861-[Plotting]- INFO    Start Plotting calibration curves at 51cm , 40kV
# 2019-11-29 10:38:12,870-[Plotting]- INFO    Start Plotting calibration curves at 51cm , 30kV

# %% [markdown]
# ## Measurement of the dose drope due to AL filter

# %%
p.dose_drop(stdev=0.04, PdfPages=PdfPages, Directory=Directory,depth= ["3cm", "5cm", "8cm", "51cm"],Voltages=["40kV", "30kV"])

# %% [markdown]
# ## The Effect of the Tube Voltage

# %%
p.dose_voltage(PdfPages=PdfPages, Directory=Directory, test="without_Al_Filter", kafe_Fit=True, table=False)

# %% [markdown]
# ## Power calculation of the tube

# %%
p.power_2d(PdfPages=PdfPages, Directory=Directory, V_limit=50, I_limit=50)

# %% [markdown]
# ## Beam profile 3D

# %%
p.Plot_Beam_profile_3d(Directory=Directory, PdfPages=PdfPages, depth=["3cm", "8cm", "51cm","60cm"])
# Out:
# 2019-11-29 10:38:57,415-[Plotting]- INFO    Make a 3d scan at specific depth

# %% [markdown]
# ## Beam profile 2D

# %%
p.Plot_Beam_profile_2d(Directory=Directory, PdfPages=PdfPages, depth=["3cm", "3cm_Vfilter", "3cm_Zrfilter", "3cm_collimator", "8cm", "60cm"])

# %%
p.plot_beamspot(Directory= Directory, depth =["60cm"], PdfPages=PdfPages)

# %%
p.close(PdfPages=PdfPages)
print("All the results are saved in the directory %s" %(Directory))
print ("The whole plots are saved into the  file %s"%(pdf_file))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d754f6b51edd> in <module>
# ----> 1 p.close(PdfPages=PdfPages)
#       2 print("All the results are saved in the directory %s" %(Directory))
#       3 print ("The whole plots are saved into the  file %s"%(pdf_file))
#
# NameError: name 'p' is not defined
